# %%
# %load_ext autoreload
# %autoreload 2
import sys
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
plt.style.use('ggplot')
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from parameters import *
from static import *
from data_frame import *
from helper import *
import calmap
import bokeh
from bokeh.models.annotations import Title
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
calmap
# Out:
# <module 'calmap' from '/usr/local/lib/python3.7/site-packages/calmap/__init__.py'>

# %%
data_frame('../data/SPLK.csv', reference_date, current_date, moveback_date).data_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2019-07-23 to 2020-07-20
# Data columns (total 11 columns):
# Date                251 non-null object
# Open                251 non-null float64
# High                251 non-null float64
# Low                 251 non-null float64
# Close               251 non-null float64
# Adj Close           251 non-null float64
# Volume              251 non-null int64
# Noramlized_Close    251 non-null float64
# Diff                251 non-null float64
# Pct_Diff            251 non-null float64
# Normalized_Diff     251 non-null float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 23.5+ KB

# %%
data = data_frame('../data/SPLK.csv', reference_date, current_date, moveback_date).df
data.head()
# Out:
#                   Date        Open        High         Low       Close  \
# Date
# 2019-07-23  2019-07-23  139.080002  139.440002  136.220001  137.770004
# 2019-07-24  2019-07-24  137.350006  140.149994  136.630005  139.960007
# 2019-07-25  2019-07-25  139.820007  139.889999  137.809998  138.740005
# 2019-07-26  2019-07-26  139.770004  142.059998  139.429993  140.729996
# 2019-07-29  2019-07-29  141.000000  141.360001  134.710007  138.220001
#
#              Adj Close   Volume  Noramlized_Close      Diff  Pct_Diff  \
# Date
# 2019-07-23  137.770004   843700          1.439453 -0.929993 -0.006705
# 2019-07-24  139.960007   937000          1.462334  2.190003  0.015896
# 2019-07-25  138.740005  1071300          1.449587 -1.220002 -0.008717
# 2019-07-26  140.729996  1089500          1.470379  1.989991  0.014343
# 2019-07-29  138.220001   976700          1.444154 -2.509995 -0.017836
#
#             Normalized_Diff
# Date
# 2019-07-23        -0.009717
# 2019-07-24         0.022882
# 2019-07-25        -0.012747
# 2019-07-26         0.020792
# 2019-07-29        -0.026225

# %%
fig, axs = plt.subplots(4, 1, figsize=(30,24))
for filepath, ax in zip(filepaths, axs):
    test = data_frame(filepath, reference_date, current_date, moveback_date).df
    series = test['Close']
    create_heatmap(ax, fig, series)
    ax.set_title(f'{refer[filepath]} Stock Closing Price($) in 2020', fontdict=font, size=30)
    set_axis_sizes(ax, 30)
    
fig.tight_layout()
# plt.savefig('../figures/heatmap.png')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Baseline

# %%
fig, ax = plt.subplots(figsize=(24, 8))
data = data_frame('../data/GSPC.csv', reference_date, current_date, moveback_date)
ax.plot(data.df.index, data.df['Close'], color='k', label='S&P 500', linewidth=2)
ax.legend(loc='upper left', prop={'size': 20})
ax.set_title('Daily Closing Price ($) for S&P 500', fontdict=font)

plot_vlines(ax, [data.reference_date, data.moveback_date, data.current_date], [2100, 3500], ['#C0392B', '#C0392B', '#C0392B'], ['dashed', 'dashed', 'dashed'], [4,4,4])
put_text(ax, [data.moveback_date,data.reference_date,data.current_date], [3200,3200,2700], [r'Oct 15, 2019', r'March 16, 2020', r'July 20, 2020'], [font,font,font], ['left', 'left', 'right'])

ax.xaxis.set_tick_params(rotation=75)
set_axis_sizes(ax)

ax.set_ylim(2100, 3500)
ax.set_xlim(data.start_date, data.current_date)
ax.set_xlabel('Time in Days', fontdict=font)
ax.set_ylabel('Stock Price ($)', fontdict=font)
fig.tight_layout()
plt.savefig('../figures/baseline.png')

# %% [markdown]
# ### Test Date

# %%
fig, ax = plt.subplots(figsize=(30, 18))

for filepath,color in zip(filepaths, colors):
    data = data_frame(filepath, reference_date, current_date, moveback_date)
    ax.plot(data.df.index, data.df['Close'], color=color, label=refer[filepath], linewidth=2)

plot_vlines(ax, [data.reference_date, data.moveback_date, data.current_date], [0, 200], ['#C0392B', '#C0392B', '#C0392B'], ['dashed', 'dashed', 'dashed'], [4,4,4])
put_text(ax, [data.moveback_date,data.reference_date,data.current_date], [200,200,125], [r'Oct 15, 2019', r'March 16, 2020', r'July 20, 2020'], [font,font,font], ['left', 'left', 'right'])

ax.legend(loc='best', prop={'size': 20});
ax.set_title(test_data_prop['plot_title'], fontdict=font);
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, 20));
ax.xaxis.set_tick_params(rotation=75)

set_axis_sizes(ax, size=18)

ax.set_ylim(0, 210)
ax.set_xlabel('Time in Days', fontdict=font)
ax.set_ylabel('Stock Price ($)', fontdict=font)
ax.set_xlim(pd.to_datetime('2019-07-24'), data.current_date)

ax.text(pd.to_datetime('2019-09-19'), 40, r'Datadog became public', fontdict=font, horizontalalignment='right', bbox=dict(facecolor='#A569BD', alpha=0.5))
ax.text(pd.to_datetime('2019-08-01'), 12, r'Dynatrace became public', fontdict=font, horizontalalignment='left', bbox=dict(facecolor='#58D68D', alpha=0.5))
fig.tight_layout()
plt.savefig('../figures/comparison.png')

# %% [markdown]
# # Test Statistics
# * Take difference shift(-1)
# * Take 120 difference points after covid and 120 before covid
# * Compute {mean, stardard deviation} of the before and after data
# * Plot normal curves and run a p test

# %%
before_after_dict = dict()
statistics = dict()

for filepath in filepaths:
    data = data_frame(filepath, reference_date, current_date, moveback_date).before_after
    before, after = data.before, data.after

    before_after_dict[refer[filepath]] = {'before': before['Pct_Diff'],'after': after['Pct_Diff']}
    statistics[refer[filepath]] = \
         {
             'before': 
             {
              'mean': round(before['Pct_Diff'].mean(),3), 
              'std':  round(before['Pct_Diff'].std(), 3), 
              'se':   round(before['Pct_Diff'].sem(), 3)
             },
              'after': 
             {
              'mean': round(after['Pct_Diff'].mean(), 3), 
              'std':  round(after['Pct_Diff'].std(), 3), 
              'se':   round(after['Pct_Diff'].sem(), 3)
              }
        }

# %%
pd.DataFrame(statistics)
# Out:
#                                              Splunk  \
# before  {'mean': -0.001, 'std': 0.035, 'se': 0.003}
# after     {'mean': 0.01, 'std': 0.041, 'se': 0.004}
#
#                                            Datadog  \
# before   {'mean': -0.0, 'std': 0.046, 'se': 0.004}
# after   {'mean': 0.014, 'std': 0.044, 'se': 0.005}
#
#                                          Dynatrace  \
# before  {'mean': 0.001, 'std': 0.042, 'se': 0.004}
# after    {'mean': 0.01, 'std': 0.041, 'se': 0.004}
#
#                                           New Relic
# before  {'mean': -0.004, 'std': 0.033, 'se': 0.003}
# after    {'mean': 0.007, 'std': 0.038, 'se': 0.004}

# %% [markdown]
# |           |               |     Splunk    |     Datadog   |   Dynatrace   |   New Relic  |
# |-----------|:-------------:|:-------------:|:-------------:|:-------------:|--------------|
# |Before/On  | Mean          |  -0.228    |  -0.039    |   0.008   |  -0.222   |
# |3/16/20    | Std. Dev.     |   4.612    |   1.699    |    1.101   |   1.781   |
# |           | Std. Error    |0.45|0.166|0.107|0.174|
# |After      | Mean          |1.28|0.733|0.275|0.326|
# |3/16/20    | Std. Dev.     |5.582|2.727|1.263|1.983|
# |           | Std. Error    |0.598|0.292|0.135|0.213

# %%
a, b = confidence_interval(before_mean, before_se, '99%').values()

# %%
fig, axs = plt.subplots(4, 1, figsize=(30, 24))

for filepath, ax  in zip(filepaths, axs):
    data = data_frame(filepath, reference_date, current_date, moveback_date).before_after
    before, after = data.before, data.after
    ax.scatter(before.index, before["Pct_Diff"], color='b', label='10/15/19-03/16/20')
    ax.scatter(after.index, after["Pct_Diff"], color='r', label='03/17/20--7/20/20')
    
    
    before_mean,before_se=statistics[refer[filepath]]['before']['mean'], statistics[refer[filepath]]['before']['se']
    after_mean, after_se=statistics[refer[filepath]]['after']['mean'], statistics[refer[filepath]]['after']['se']
    before_lower, before_upper = confidence_interval(before_mean, before_se, '99%').values()
    after_lower, after_upper = confidence_interval(after_mean, after_se, '99%').values()
    
    plot_hlines(ax, [before_lower, before_mean, before_upper], [data.moveback_date, data.reference_date], ['k', 'k', 'k'], ['dashed', 'solid', 'dashed'])
    plot_hlines(ax, [after_lower, after_mean, after_upper], [data.reference_date, data.current_date], ['k', 'k', 'k'], ['dashed', 'solid', 'dashed'])

    
    start, end = ax.get_xlim()
    ax.xaxis.set_ticks(np.arange(start, end, 20));
    ax.set_title(refer[filepath] + ': % Difference in Daily Closing Price 120 Days Before and After March 16, 2020', fontdict=font, size=36);
    ax.set_xlim((data.moveback_date, data.current_date))
    ax.legend(loc='lower left', prop={'size': 26})
    ax.tick_params(axis='x', labelsize=24)
    ax.tick_params(axis='y', labelsize=24)
    ax.set_xlabel('Time in Days',fontdict=font, size=30)
    ax.set_ylabel('% Diff',fontdict=font, size=30)
    set_axis_sizes(ax, size=24)
    start, end = ax.get_xlim()
    ax.xaxis.set_ticks(np.arange(start, end, 20));
#     ax.xaxis.set_tick_params(rotation=75)
    
    
fig.tight_layout();
plt.savefig('../figures/before_after_diff_distribution.png')

# %% [markdown]
# ## Plot distributions before and after March 16, 2020

# %%
# fig, axs = plt.subplots(4, 2, figsize=(30, 18))
# plots = axs.flatten()
# for filepath, ax  in zip(filepaths, axs):
#     data = data_frame(filepath, reference_date, current_date, moveback_date).before_after
#     before, after = data.before, data.after
#     ax[0].hist(after["Pct_Diff"], bins=100, color='r')
#     ax[0].set_title(refer[filepath] + ': Daily % Difference 120 Days After March 15, 2020', fontdict=font)
#     ax[1].hist(before["Pct_Diff"], bins=100, color='b')
#     ax[1].set_title(refer[filepath] + ': Daily % Difference 120 Days Before March 15, 2020', fontdict=font)
#     ax[0].tick_params(axis='x', labelsize=18)
#     ax[0].tick_params(axis='y', labelsize=18)
#     ax[1].tick_params(axis='x', labelsize=18)
#     ax[1].tick_params(axis='y', labelsize=18)
#     set_axis_sizes(ax[0])
#     set_axis_sizes(ax[1])


# fig.tight_layout();
# #plt.savefig('../figures/before_after_Histogram_Normalized_Diff.png')

# %%
def cdf(value, array):
    return (array<value).sum()/len(array)

vcdf = np.vectorize(cdf, excluded = ['array'])

# %%
cdf1 = vcdf(value = before["Normalized_Diff"], array = before["Normalized_Diff"])
cdf2 = vcdf(value = after["Normalized_Diff"], array = after["Normalized_Diff"])
plt.scatter(before["Normalized_Diff"], cdf1, label='before/on Mar. 16')
plt.scatter(after["Normalized_Diff"], cdf2, label='after Mar. 16')
plt.legend()

# %%
fig, axs = plt.subplots(2, 2, figsize=(30, 18))
plots = axs.flatten()
bayesian_count = dict()
for filepath, ax, c  in zip(filepaths, axs.flatten(), np.arange(8)):
    data = data_frame(filepath, reference_date, current_date, moveback_date).before_after
    before, after = data.before, data.after
    cdf1 = vcdf(value = before["Pct_Diff"], array = before["Pct_Diff"])
    cdf2 = vcdf(value = after["Pct_Diff"], array = after["Pct_Diff"])
    before_count = before[before["Pct_Diff"]>0]['Pct_Diff'].count() / before['Pct_Diff'].count()
    after_count = after[after["Pct_Diff"]>0]['Pct_Diff'].count() / after['Pct_Diff'].count()
    before_count = round(before_count, 2)
    after_count = round(after_count, 2)
    ax.scatter(before["Pct_Diff"], cdf1, label=f'10/15/19-03/16/20 ({before_count})', color='b')
    ax.scatter(after["Pct_Diff"], cdf2, label=f'03/17/20-07/20/20 ({after_count})', color='r')
    ax.set_title(refer[filepath] + ': Cumulative % Daily Change', fontdict=font, size=36)
    ax.vlines(0.0, 0.0, 1.0)
    ax.set_ylim(0.0, 1.0)
    set_axis_sizes(ax, size=24)
    ax.legend(loc='best', prop={'size': 24})
    ax.set_xlabel('% Daily Change',fontdict=font, size=30)
    ax.set_ylabel('Cumulative Sum',fontdict=font, size=30)
    bayesian_count[refer[filepath]] = \
                                    {
                                    'before': {'positive': before_count, 'negative': 1-before_count, 'count': before['Pct_Diff'].count()},
                                    'after' : {'positive': after_count, 'negative': 1-after_count, 'count': after['Pct_Diff'].count()}
                                    }
        
fig.tight_layout();
fig.savefig('../figures/cumul.png')

# %%
filepaths
# Out:
# ['../data/SPLK.csv', '../data/DDOG.csv', '../data/DT.csv', '../data/NEWR.csv']

# %% [markdown]
# ## T-test on before and after data

# %%
hyp_test = dict()
for filepath in filepaths:
    data = data_frame(filepath, reference_date, current_date, moveback_date).before_after
    before, after = data.before['Normalized_Diff'], data.after['Normalized_Diff']
    stat, p_val = stats.ttest_ind(before, after, axis=0, equal_var=False, nan_policy='omit')
    
    hyp_test[refer[filepath]] = {'t_stat': stat, 'p_val': p_val}

pd.DataFrame(hyp_test)
# Out:
#           Splunk   Datadog  Dynatrace  New Relic
# t_stat -2.014599 -2.298923  -1.544077  -1.998822
# p_val   0.045554  0.023007   0.124407   0.047177

# %% [markdown]
# |               |     Splunk    |     Datadog   |   Dynatrace   |   New Relic  |
# | ------------- |:-------------:|:-------------:|:-------------:|--------------|
# | t_stat        |  -2.014599    |  -2.298923    |   -1.544077   |  -1.998822   |
# | p_value       |   0.045554    |   0.023007    |    0.124407   |   0.047177   |

# %%
sp_data = data_frame('../data/GSPC.csv', reference_date, current_date, moveback_date).before_after

# %%
before, after = sp_data.before['Normalized_Diff'], sp_data.after['Normalized_Diff']

# %%
stat, p_val = stats.ttest_ind(before, after, axis=0, equal_var=False, nan_policy='omit')

# %%
stat, p_val
# Out:
# (-1.663064041412699, 0.09799249422641083)

# %% [markdown]
# ### Stationary Test

# %%
data = data_frame('../data/NEWR.csv', reference_date, current_date, moveback_date).before_after
before, after = data.before, data.after

# %%
adfuller(after['Pct_Diff'])
# Out:
# (-9.94173917906023,
#  2.6532228493611306e-17,
#  0,
#  86,
#  {'1%': -3.5087828609430614,
#   '5%': -2.895783561573195,
#   '10%': -2.5850381719848565},
#  -294.3184012733062)

# %%
refer
# Out:
# {'../data/SPLK.csv': 'Splunk',
#  '../data/DDOG.csv': 'Datadog',
#  '../data/DT.csv': 'Dynatrace',
#  '../data/NEWR.csv': 'New Relic'}

# %%
stationary = dict()
col='Pct_Diff'
for filepath in filepaths:
    stationary[refer[filepath]] = stationarity_test(filepath,col, reference_date, current_date, moveback_date)

# %%
pd.DataFrame(stationary)
# Out:
#                                                    Splunk  \
# before  {'ADF': -0.7431153604267446, 'p-value': 0.8352...
# after   {'ADF': -6.176711256832059, 'p-value': 6.60363...
#
#                                                   Datadog  \
# before  {'ADF': -9.193318155982068, 'p-value': 2.09474...
# after   {'ADF': -10.718345904646185, 'p-value': 3.1981...
#
#                                                 Dynatrace  \
# before  {'ADF': -3.5771163122270155, 'p-value': 0.0062...
# after   {'ADF': -9.69720512505198, 'p-value': 1.096253...
#
#                                                 New Relic
# before  {'ADF': -4.133036836860251, 'p-value': 0.00085...
# after   {'ADF': -9.94173917906023, 'p-value': 2.653222...

# %%
stationarity_test('../data/GSPC.csv', 'Pct_Diff', reference_date, current_date, moveback_date)
# Out:
# {'before': {'ADF': 0.47950673325471843,
#   'p-value': 0.984236728660709,
#   '1%': -3.502704609582561,
#   '5%': -2.8931578098779522,
#   '10%': -2.583636712914788},
#  'after': {'ADF': -7.871253723783716,
#   'p-value': 4.9781650082343155e-12,
#   '1%': -3.5117123057187376,
#   '5%': -2.8970475206326833,
#   '10%': -2.5857126912469153}}

# %% [markdown]
# ### Bayesian Test

# %%
data = data_frame('../data/GSPC.csv', reference_date, current_date, moveback_date).before_after
before, after = data.before, data.after

# %%
bayesian_count
# Out:
# {'Splunk': {'before': {'positive': 0.53, 'negative': 0.47, 'count': 105},
#   'after': {'positive': 0.63, 'negative': 0.37, 'count': 87}},
#  'Datadog': {'before': {'positive': 0.5, 'negative': 0.5, 'count': 105},
#   'after': {'positive': 0.67, 'negative': 0.32999999999999996, 'count': 87}},
#  'Dynatrace': {'before': {'positive': 0.51, 'negative': 0.49, 'count': 105},
#   'after': {'positive': 0.62, 'negative': 0.38, 'count': 87}},
#  'New Relic': {'before': {'positive': 0.47, 'negative': 0.53, 'count': 105},
#   'after': {'positive': 0.55, 'negative': 0.44999999999999996, 'count': 87}}}

# %%
fig, axs = plt.subplots(2, 2, figsize=(30,18))
x = np.arange(0, 1.01, 0.001)
for filepath,ax in zip(filepaths, axs.flatten()):
    col=refer[filepath]
    positive_before, negative_before, count_before = bayesian_count[col]['before']['positive'], bayesian_count[col]['before']['negative'], bayesian_count[col]['before']['count']
    positive_after, negative_after, count_after = bayesian_count[col]['after']['positive'], bayesian_count[col]['after']['negative'], bayesian_count[col]['after']['count']
    plot_with_fill(ax, x, stats.beta(count_before*positive_before, count_before*negative_before).pdf(x), label=f'10/15/19-03/16/20', color='b')
    plot_with_fill(ax, x, stats.beta(count_after*positive_after, count_after*negative_after).pdf(x), label=f'03/17/20-07/20/20', color='r')
    set_axis_limits(ax)
    ax.set_title(f'Bayesian A/B Testing for {col}', fontdict=font, size=36)
    ax.legend(loc='best', prop={'size': 24})
    ax.set_xlabel('Probability of Positive % Daily Change',fontdict=font, size=30)
    ax.set_ylabel('Posterior after 87 Views',fontdict=font, size=30)
    set_axis_sizes(ax, size=24)
fig.tight_layout(); 
plt.savefig('../figures/bayesian_test.png')

# %%
# (positive_before, negative_before, count_before), (positive_after, neagative_after, count_after)
bayesian_count['Splunk']['after']['negative']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-f6982d799cd7> in <module>
#       1 # (positive_before, negative_before, count_before), (positive_after, neagative_after, count_after)
# ----> 2 bayesian_count['Splunk']['after']['negative']
#
# KeyError: 'Splunk'

# %%
plot_with_fill(ax, x, stats.beta(count_before*alpha_before, count_before*beta_before).pdf(x), label=f'{col} Before')
plot_with_fill(ax, x, stats.beta(count_after*alpha_after, count_after*beta_after).pdf(x), label=f'{col} After')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-73ed37d9fb46> in <module>
# ----> 1 plot_with_fill(ax, x, stats.beta(count_before*alpha_before, count_before*beta_before).pdf(x), label=f'{col} Before')
#       2 plot_with_fill(ax, x, stats.beta(count_after*alpha_after, count_after*beta_after).pdf(x), label=f'{col} After')
#       3
#       4
#
# NameError: name 'count_before' is not defined

# %% [markdown]
# ### Trying out

# %%
def plot_beta(alpha, beta, ax, title=None, label=None, xticks=[0.0, 0.5, 1.0]):

    # Build a beta distribtuion scipy object.
    dist = stats.beta(alpha, beta)

    # The support (always this for the beta dist).
    x = np.linspace(0.0, 1.0, 301)

    # The probability density at each sample support value.
    y = dist.pdf(x)

    # Plot it all.
    lines = ax.plot(x, y, label=label)
    ax.fill_between(x, y, alpha=0.2, color=lines[0].get_c())
    if title: 
        ax.set_title(title)
    ax.get_yaxis().set_ticks([])
    #ax.get_yaxis().set_ticks([np.max(y)])
    ax.get_xaxis().set_ticks(xticks)
    ax.set_ylim(0.0, np.max(y)*1.2)

# %%
# The shape parameters.
alpha_values = [1, 2, 4, 8, 16, 32]  
beta_values  = [1, 2, 4, 8, 16, 32]
n_rows, n_cols = len(alpha_values), len(beta_values)
alpha_beta_pairs = ( (i, j) for i in alpha_values for j in beta_values )

# Create a large figure - nice way to do it.
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 15))

# Plot each beta dist. One plot per pair of shape params.
for (alpha, beta), ax in zip(alpha_beta_pairs, axes.flatten()):
    plot_beta(alpha, beta, ax, r"$\alpha={} ,  \beta={}$".format(alpha, beta))

plt.tight_layout()

# %%
bayesian_count['Splunk']
# Out:
# {'before': {'alpha': 0.53, 'beta': 0.47},
#  'after': {'alpha': 0.63, 'beta': 0.37}}

# %%
for filepath  in filepaths:
    data = data_frame(filepath, reference_date, current_date, moveback_date).before_after
    before, after = data.before, data.after

# %%
before['p'].count()
# Out:
# Date                105
# Open                105
# High                105
# Low                 105
# Close               105
# Adj Close           105
# Volume              105
# Noramlized_Close    105
# Diff                105
# Pct_Diff            105
# Normalized_Diff     105
# dtype: int64

# %%
for filepath in filepaths:
    print(type(refer[filepath]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# # Plot dynamic evolution with bayes

# %%
fig, axs = plt.subplots(2, 2, figsize=(30, 18))
x = np.arange(0, 1.01, 0.001)
bayesian_count = dict()
for filepath, ax  in zip(filepaths, axs.flatten()):
    col=refer[filepath]
    for mov, cur, color in bayes_intervals:
        data = data_frame(filepath, reference_date, cur, mov).chunk.part
        positive_count = data[data["Pct_Diff"]>0]['Pct_Diff'].count() 
        negative_count = data[data["Pct_Diff"]<0]['Pct_Diff'].count()
        plot_with_fill(ax, x, stats.beta(positive_count, negative_count).pdf(x), label=f'({mov[5:]} to {cur[5:]})', color=color)
    ax.set_title(refer[filepath] + ': Monthly Bayesian A/B Testing', fontdict=font, size=36)
    set_axis_sizes(ax)
    ax.legend(loc='best', prop={'size': 20})
    ax.set_xlabel('Probability of Positive % Daily Change',fontdict=font, size=30)
    ax.set_ylabel('Posterior for Each Month',fontdict=font, size=30)
    set_axis_sizes(ax, size=24)
        
fig.tight_layout(); 
plt.savefig('../figures/monthly_evolution.png')

# %%
fig, axs = plt.subplots(2, 2, figsize=(30,15))
x = np.arange(0, 1.01, 0.001)
for filepath,ax in zip(filepaths, axs.flatten()):
    col=refer[filepath]
    positive_before, negative_before, count_before = bayesian_count[col]['before']['positive'], bayesian_count[col]['before']['negative'], bayesian_count[col]['before']['count']
    positive_after, negative_after, count_after = bayesian_count[col]['after']['positive'], bayesian_count[col]['after']['negative'], bayesian_count[col]['after']['count']
    plot_with_fill(ax, x, stats.beta(count_before*alpha_before, count_before*beta_before).pdf(x), label=f'{col} Before')
    plot_with_fill(ax, x, stats.beta(count_after*alpha_after, count_after*beta_after).pdf(x), label=f'{col} After')

    ax.legend()
    
    fig, axs = plt.subplots(2, 2, figsize=(30,15))
x = np.arange(0, 1.01, 0.001)
for filepath,ax in zip(filepaths, axs.flatten()):
    col=refer[filepath]
    positive_before, negative_before, count_before = bayesian_count[col]['before']['positive'], bayesian_count[col]['before']['negative'], bayesian_count[col]['before']['count']
    positive_after, negative_after, count_after = bayesian_count[col]['after']['positive'], bayesian_count[col]['after']['negative'], bayesian_count[col]['after']['count']
    plot_with_fill(ax, x, stats.beta(count_before*alpha_before, count_before*beta_before).pdf(x), label=f'{col} Before')
    plot_with_fill(ax, x, stats.beta(count_after*alpha_after, count_after*beta_after).pdf(x), label=f'{col} After')

    ax.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-185-1f46f22cca7b> in <module>
#       3 for filepath,ax in zip(filepaths, axs.flatten()):
#       4     col=refer[filepath]
# ----> 5     positive_before, negative_before, count_before = bayesian_count[col]['before']['positive'], bayesian_count[col]['before']['negative'], bayesian_count[col]['before']['count']
#       6     positive_after, negative_after, count_after = bayesian_count[col]['after']['positive'], bayesian_count[col]['after']['negative'], bayesian_count[col]['after']['count']
#       7     plot_with_fill(ax, x, stats.beta(count_before*alpha_before, count_before*beta_before).pdf(x), label=f'{col} Before')
#
# KeyError: 'Splunk'

# %%
dy_param_list = ['2020-03-16', '2020-04-16', '2020-05-16', '2020-06-16', '2020-07-16'] 

list(zip(dy_param_list[:-1], dy_param_list[1:]))
# Out:
# [('2020-03-16', '2020-04-16'),
#  ('2020-04-16', '2020-05-16'),
#  ('2020-05-16', '2020-06-16'),
#  ('2020-06-16', '2020-07-16')]

# %%
dy_param_list[1:]
# Out:
# ['2020-04-16', '2020-05-16', '2020-06-16', '2020-07-16']

# %%
for cur, mov in bayes_intervals:
    print(cur, mov)
# Out:
# 2020-03-16 2020-04-16
# 2020-04-16 2020-05-16
# 2020-05-16 2020-06-16
# 2020-06-16 2020-07-16

# %%
['t']*2
# Out:
# ['t', 't']

# %%
from math import pi

import pandas as pd

from bokeh.sampledata.stocks import MSFT
from bokeh.plotting import figure, show, output_file

# data_frame('../data/SPLK.csv', reference_date, current_date, moveback_date).df

# df = pd.DataFrame(MSFT)[:50]
# df["date"] = pd.to_datetime(df["date"])

df = data_frame('../data/SPLK.csv', reference_date, current_date, moveback_date).df
df["date"] = pd.to_datetime(df["Date"])


mids = (df.Open + df.Close)/2
spans = abs(df.Close-df.Open)

inc = df.Close > df.Open
dec = df.Open > df.Close
w = 12*60*60*1000 # half day in ms

output_file("candlestick.html", title="candlestick.py example")

TOOLS = "pan,wheel_zoom,box_zoom,reset,save"

p = figure(x_axis_type="datetime", tools=TOOLS, plot_width=1500, plot_height=800, toolbar_location="left")

p.segment(df.date, df.High, df.date, df.Low, color="black")
p.rect(df.date[inc], mids[inc], w, spans[inc], fill_color="#20f211", line_color="black")
p.rect(df.date[dec], mids[dec], w, spans[dec], fill_color="#ba1449", line_color="black")

t = Title()
p.title = t
t.text = "Splunk Candlestick"
p.title.align = "center"
p.title.text_font_size = '24pt'
p.xaxis.major_label_orientation = pi/4
p.grid.grid_line_alpha=0.3
p.xaxis.axis_label = 'Time in Days'
p.yaxis.axis_label = 'Stock Price($)'
p.axis.axis_label_text_font_size='20pt'
p.axis.major_label_text_font_size='20pt'

show(p)  # open a browser

# %%
bokeh.sampledata.download()
# Out:
# Creating /Users/rajatghosh/.bokeh directory
# Creating /Users/rajatghosh/.bokeh/data directory
# Using data directory: /Users/rajatghosh/.bokeh/data
# Downloading: CGM.csv (1589982 bytes)
#    1589982 [100.00%]
# Downloading: US_Counties.zip (3171836 bytes)
#    3171836 [100.00%]
# Unpacking: US_Counties.csv
# Downloading: us_cities.json (713565 bytes)
#     713565 [100.00%]
# Downloading: unemployment09.csv (253301 bytes)
#     253301 [100.00%]
# Downloading: AAPL.csv (166698 bytes)
#     166698 [100.00%]
# Downloading: FB.csv (9706 bytes)
#       9706 [100.00%]
# Downloading: GOOG.csv (113894 bytes)
#     113894 [100.00%]
# Downloading: IBM.csv (165625 bytes)
#     165625 [100.00%]
# Downloading: MSFT.csv (161614 bytes)
#     161614 [100.00%]
# Downloading: WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.zip (4816256 bytes)
#    4816256 [100.00%]
# Unpacking: WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.csv
# Downloading: gapminder_fertility.csv (64346 bytes)
#      64346 [100.00%]
# Downloading: gapminder_population.csv (94509 bytes)
#      94509 [100.00%]
# Downloading: gapminder_life_expectancy.csv (73243 bytes)
#      73243 [100.00%]
# Downloading: gapminder_regions.csv (7781 bytes)
#       7781 [100.00%]
# Downloading: world_cities.zip (645274 bytes)
#     645274 [100.00%]
# Unpacking: world_cities.csv
# Downloading: airports.json (6373 bytes)
#       6373 [100.00%]
# Downloading: movies.db.zip (5053420 bytes)
#    5053420 [100.00%]
# Unpacking: movies.db
# Downloading: airports.csv (203190 bytes)
#     203190 [100.00%]
# Downloading: routes.csv (377280 bytes)
#     377280 [100.00%]
# Downloading: haarcascade_frontalface_default.xml (930127 bytes)
#     930127 [100.00%]

# %%
df = data_frame('../data/SPLK.csv', reference_date, current_date, moveback_date).df

# %%
df["Date"]
# Out:
# Date
# 2019-07-23    2019-07-23
# 2019-07-24    2019-07-24
# 2019-07-25    2019-07-25
# 2019-07-26    2019-07-26
# 2019-07-29    2019-07-29
#                  ...
# 2020-07-14    2020-07-14
# 2020-07-15    2020-07-15
# 2020-07-16    2020-07-16
# 2020-07-17    2020-07-17
# 2020-07-20    2020-07-20
# Name: Date, Length: 251, dtype: object

# %%
df.head()
# Out:
#                   Date        Open        High         Low       Close  \
# Date
# 2019-07-23  2019-07-23  139.080002  139.440002  136.220001  137.770004
# 2019-07-24  2019-07-24  137.350006  140.149994  136.630005  139.960007
# 2019-07-25  2019-07-25  139.820007  139.889999  137.809998  138.740005
# 2019-07-26  2019-07-26  139.770004  142.059998  139.429993  140.729996
# 2019-07-29  2019-07-29  141.000000  141.360001  134.710007  138.220001
#
#              Adj Close   Volume  Noramlized_Close      Diff  Pct_Diff  \
# Date
# 2019-07-23  137.770004   843700          1.439453 -0.929993 -0.006705
# 2019-07-24  139.960007   937000          1.462334  2.190003  0.015896
# 2019-07-25  138.740005  1071300          1.449587 -1.220002 -0.008717
# 2019-07-26  140.729996  1089500          1.470379  1.989991  0.014343
# 2019-07-29  138.220001   976700          1.444154 -2.509995 -0.017836
#
#             Normalized_Diff       date
# Date
# 2019-07-23        -0.009717 2019-07-23
# 2019-07-24         0.022882 2019-07-24
# 2019-07-25        -0.012747 2019-07-25
# 2019-07-26         0.020792 2019-07-26
# 2019-07-29        -0.026225 2019-07-29
